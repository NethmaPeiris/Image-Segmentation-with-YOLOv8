# %%
# !nvidia-smi
# Out:
# Mon May  6 18:28:25 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
#install ultralytics
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 kB 4.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
import os
from IPython import display
display.clear_output()
# !yolo mode =checks

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 524, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are {'val', 'predict', 'track', 'benchmark', 'train', 'export'}.
#
#     Arguments received: ['yolo', 'mode', '=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of {'classify', 'segment', 'pose', 'obb', 'detect'}
#                 MODE (required) is one of {'val', 'predict', 'track', 'benchmark', 'train', 'export'}
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %% [markdown]
# # Instance Segmentation Example with Pretrained Model

# %%
# !yolo task=segment mode=predict model=yolov8l-seg.pt conf=0.4 source='https://media.roboflow.com/notebooks/examples/dog.jpeg'
# Out:
# ...
# 100% 88.1M/88.1M [00:00<00:00, 227MB/s]
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45973568 parameters, 0 gradients, 220.5 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 83.3MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 247.7ms
# Speed: 11.5ms preprocess, 247.7ms inference, 3521.4ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='/content/runs/segment/predict/dog.jpeg',height=600)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="LlFiySP0EZWifT3EypN4")
project = rf.workspace("yolov8-alqlt").project("shujv-rsolh")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
# ...

# %%
# !yolo task=segment mode=train model=yolov8l-seg.pt data='/content/SHUJV-6/data.yaml' epochs=15 imgsz=640
# Out:
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs/segment/train3/weights/best.pt' conf=0.77 source='/content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/test_video_1_p_2.mp4'
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (frame 8590/13586) /content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/test_video_1_p_2.mp4: 384x640 2 a-cars, 3 b-riders, 1 e-person, 1 h-sidewalk, 23.6ms
# video 1/1 (frame 8591/13586) /content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/test_video_1_p_2.mp4: 384x640 2 a-cars, 4 b-riders, 1 h-sidewalk, 23.3ms
# video 1/1 (frame 8592/13586) /content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/test_video_1_p_2.mp4: 384x640 2 a-cars, 3 b-riders, 24.6ms
# video 1/1 (frame 8593/13586) /content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/test_video_1_p_2.mp4: 384x640 2 a-cars, 5 b-riders, 1 e-person, 24.4ms
# video 1/1 (frame 8594/13586) /content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/test_video_1_p_2.mp4: 384x640 2 a-cars, 2 b-riders, 1 e-person, 1 h-sidewalk, 23.4ms
# ...

# %%
import shutil

# Define paths
source_path = '/content/runs/segment/predict2/test_video_1_p_2.avi'
destination_path = '/content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/outputs/test_video_1_p_2.avi'

# Copy file from source to destination
shutil.copyfile(source_path, destination_path)

print("File saved to Google Drive successfully!")
# Out:
# File saved to Google Drive successfully!

# %%
# !yolo task=detect mode=predict model='/content/runs/segment/train3/weights/best.pt' conf=0.77 source='/content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/test_video_2_p_2.mp4'
# Out:
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=segment' model. Ignoring 'task=detect' and updating to 'task=segment' to match model.
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45921911 parameters, 0 gradients, 220.2 GFLOPs
#
# video 1/1 (frame 1/4085) /content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/test_video_2_p_2.mp4: 384x640 1 f-road, 183.4ms
# video 1/1 (frame 2/4085) /content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/test_video_2_p_2.mp4: 384x640 1 f-road, 48.1ms
# video 1/1 (frame 3/4085) /content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/test_video_2_p_2.mp4: 384x640 1 f-road, 48.1ms
# video 1/1 (frame 4/4085) /content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/test_video_2_p_2.mp4: 384x640 1 f-road, 48.1ms
# ...

# %%
import shutil

# Define paths
source_path = '/content/runs/segment/predict3/test_video_2_p_2.avi'
destination_path = '/content/drive/MyDrive/Computer Vision Projects/Yolo Projects/pedestrian project/outputs/test_video_2_p_2.avi'

# Copy file from source to destination
shutil.copyfile(source_path, destination_path)

print("File saved to Google Drive successfully!")
# Out:
# File saved to Google Drive successfully!
